# %% [markdown]
# # 第2章 行列は変形の機械
#
# 『Pythonで学び直す線形代数』第2章のサンプルコードです。
#
# **使い方**
#
# 1. まず下の「設定セル」のセルを選んで、左の「▶」を押す(または Shift+Enter)。1回だけでOKです。
# 2. あとは各 LESSON のコードを、上から順に「▶」で実行してください。
# 3. 本の説明を読みながら試すと、いちばんよく分かります。
#
# コードは書きかえて何度でも試せます。数字を1つ変えて ▶ を押すと、結果がどう変わるかを目で確かめられます。

# %% [markdown]
# ## 設定セル(最初に1回だけ実行)
#
# 日本語をグラフに表示するための準備です。新しく開いたら、まずこのセルを1回実行してください。

# %%
# 設定セル(このノートブックで最初に1回だけ実行してください)
# 日本語をグラフに表示するための準備です
# !pip install matplotlib-fontja -q
import matplotlib_fontja  # noqa: F401
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["font.size"] = 18           # グラフの文字を大きめに
plt.rcParams["figure.figsize"] = (8, 6)  # グラフ自体を大きめに

# %% [markdown]
# ## LESSON 05 平面ぜんたいを、一度に動かす
#
# 本書の「LESSON 05 平面ぜんたいを、一度に動かす」の説明を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# (この LESSON にコードはありません)

# %% [markdown]
# ## LESSON 06 行き先を2本だけ書き留める
#
# 本書の「LESSON 06 行き先を2本だけ書き留める」の説明を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %%
e1_go = np.array([2, 1])   # 横に真っ直ぐの矢印の行き先
e2_go = np.array([1, 1])   # 縦に真っ直ぐの矢印の行き先

A = np.array([[2, 1], [1, 1]])
print(A)

# %%
print(A[:, 0])
print(A[:, 1])

# %%
v = np.array([1, 2])
print(v[0] * A[:, 0] + v[1] * A[:, 1])

# %% [markdown]
# ## LESSON 07 掛け算を、自分の手で書く
#
# 本書の「LESSON 07 掛け算を、自分の手で書く」の説明を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %%
def matvec(A, v):
    """行列 A で矢印 v を動かす（numpy の @ を使わずに書く）"""
    kekka = [0, 0]
    for i in range(2):          # 答えの何番目を作るか
        for j in range(2):      # 元の矢印の何番目を使うか
            kekka[i] = kekka[i] + A[i][j] * v[j]
    return np.array(kekka)


A = np.array([[2, 1], [1, 1]])
v = np.array([1, 2])
print(matvec(A, v))

# %%
print(A @ v)
print(np.allclose(matvec(A, v), A @ v))

# %%
print(np.dot(A, v))
print(np.matmul(A, v))

# %%
print(A.shape)
B = np.array([[1, 0], [0, 1], [1, 1]])
print(B.shape)
print(B @ v)

# %%
R = np.array([[0, -1], [1, 0]])
v = np.array([1, 2])
print(R @ v)

# %% [markdown]
# ## LESSON 08 4つの変形を見分ける
#
# 本書の「LESSON 08 4つの変形を見分ける」の説明を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %%
katachi = {
    "伸ばす": np.array([[2, 0], [0, 1]]),
    "回す": np.array([[0, -1], [1, 0]]),
    "倒す": np.array([[1, 1], [0, 1]]),
    "つぶす": np.array([[1, 2], [2, 4]]),
}

v = np.array([1, 1])
for namae, M in katachi.items():
    print(namae, M @ v)

# %%
rng = np.random.default_rng(42)
C = np.array([[1, 2], [2, 4]])

kaku = rng.uniform(0, 2 * np.pi, 100)
moto = np.stack([np.cos(kaku), np.sin(kaku)])
saki = C @ moto

print(np.round(saki[:, :3], 2))

# %%
print(np.round(saki[1] / saki[0], 4)[:5])
