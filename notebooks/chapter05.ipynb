# %% [markdown]
# # 第5章 元に戻せる変形、戻せない変形（逆行列）
#
# 『Pythonで学び直す線形代数』第5章のサンプルコードです。
#
# **使い方**
#
# 1. まず下の「設定セル」のセルを選んで、左の「▶」を押す(または Shift+Enter)。1回だけでOKです。
# 2. あとは各 LESSON のコードを、上から順に「▶」で実行してください。
# 3. 本の説明を読みながら試すと、いちばんよく分かります。
#
# コードは書きかえて何度でも試せます。数字を1つ変えて ▶ を押すと、結果がどう変わるかを目で確かめられます。

# %% [markdown]
# ## 設定セル(最初に1回だけ実行)
#
# 日本語をグラフに表示するための準備です。新しく開いたら、まずこのセルを1回実行してください。

# %%
# 設定セル(このノートブックで最初に1回だけ実行してください)
# 日本語をグラフに表示するための準備です
# !pip install matplotlib-fontja -q
import matplotlib_fontja  # noqa: F401
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["font.size"] = 18           # グラフの文字を大きめに
plt.rcParams["figure.figsize"] = (8, 6)  # グラフ自体を大きめに

# %% [markdown]
# ## LESSON 17 元に戻す変形を探す
#
# 本書の「LESSON 17 元に戻す変形を探す」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
A = np.array([[2.0, 1.0], [1.0, 1.0]])
B = np.array([[1.0, -1.0], [-1.0, 2.0]])

print(A @ B)
print(np.allclose(A @ B, np.eye(2)))
print(np.allclose(B @ A, np.eye(2)))

# %%
v = np.array([3.0, 1.0])
print(A @ v)
print(B @ (A @ v))

# %%
print(np.linalg.inv(A))
print(np.allclose(np.linalg.inv(A), B))

# %%
def inv2(A):
    """2行2列の逆行列を公式で作る"""
    a, b = A[0][0], A[0][1]
    c, d = A[1][0], A[1][1]
    shihai = a * d - b * c          # 戻せるかを決める数
    return np.array([[d, -b], [-c, a]]) / shihai


print(inv2(A))
print(np.allclose(inv2(A), np.linalg.inv(A)))

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

A = np.array([[2.0, 1.0], [1.0, 1.0]])
B = np.array([[1.0, -1.0], [-1.0, 2.0]])

print(A @ B)
print(np.allclose(A @ B, np.eye(2)))
print(np.allclose(B @ A, np.eye(2)))

# %% [markdown]
# ## LESSON 18 戻せない変形がある
#
# 本書の「LESSON 18 戻せない変形がある」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
C = np.array([[1.0, 2.0], [2.0, 4.0]])
print(C @ np.array([1.0, 0.0]))
print(C @ np.array([-1.0, 1.0]))

# %%
try:
    np.linalg.inv(C)
except np.linalg.LinAlgError as e:
    print("LinAlgError:", e)

# %%
for y in [2.0, 1.5, 1.2, 1.05, 1.001]:
    M = np.array([[1.0, 1.0], [1.0, y]])
    print(f"y={y}  inv の左上={np.linalg.inv(M)[0][0]:.1f}")

# %%
for y in [2.0, 1.5, 1.2, 1.05, 1.001]:
    M = np.array([[1.0, 1.0], [1.0, y]])
    print(f"y={y}  cond={np.linalg.cond(M):.1f}")

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

for y in [2.0, 1.5, 1.2, 1.05, 1.001]:
    M = np.array([[1.0, 1.0], [1.0, y]])
    print(f"y={y}  cond={np.linalg.cond(M):.1f}")

# %% [markdown]
# ## LESSON 19 逆行列で連立方程式を解かない
#
# 本書の「LESSON 19 逆行列で連立方程式を解かない」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
A = np.array([[2.0, 1.0], [1.0, 1.0]])
b = np.array([4.0, 3.0])

print(np.linalg.inv(A) @ b)
print(np.linalg.solve(A, b))

# %%
def hilbert(n):
    """つぶれかけた行列の代表例を作る"""
    return np.array([[1.0 / (i + j + 1) for j in range(n)]
                     for i in range(n)])


H = hilbert(12)
kotae = np.ones(12)
b12 = H @ kotae

print(np.max(np.abs(np.linalg.inv(H) @ b12 - kotae)))
print(np.max(np.abs(np.linalg.solve(H, b12) - kotae)))

# %%
import time

rng = np.random.default_rng(42)
n = 500
An = rng.random((n, n)) + n * np.eye(n)
bn = rng.random(n)
np.linalg.solve(An, bn)  # 準備

start = time.time()
np.linalg.inv(An) @ bn
print(f"inv で解く  : {(time.time() - start) * 1000:.1f} ミリ秒")

start = time.time()
np.linalg.solve(An, bn)
print(f"solve で解く: {(time.time() - start) * 1000:.1f} ミリ秒")

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

import time

rng = np.random.default_rng(42)
n = 500
An = rng.random((n, n)) + n * np.eye(n)
bn = rng.random(n)
np.linalg.solve(An, bn)  # 準備

start = time.time()
np.linalg.inv(An) @ bn
print(f"inv で解く  : {(time.time() - start) * 1000:.1f} ミリ秒")

start = time.time()
np.linalg.solve(An, bn)
print(f"solve で解く: {(time.time() - start) * 1000:.1f} ミリ秒")

# %% [markdown]
# ## LESSON 20 転置と逆行列を取り違えない
#
# 本書の「LESSON 20 転置と逆行列を取り違えない」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
A = np.array([[2.0, 1.0], [1.0, 1.0]])
print(A.T)
print(np.allclose(A.T, np.linalg.inv(A)))

# %%
R = np.array([[0.0, -1.0], [1.0, 0.0]])
print(R.T)
print(np.allclose(R.T, np.linalg.inv(R)))
print(R.T @ R)

# %%
for kakudo in [30, 45, 137]:
    t = np.radians(kakudo)
    Rt = np.array([[np.cos(t), -np.sin(t)],
                   [np.sin(t), np.cos(t)]])
    print(kakudo, np.allclose(Rt.T, np.linalg.inv(Rt)))

# %%
A3 = np.array([[2.0, 1.0, -1.0],
               [1.0, 3.0, 2.0],
               [1.0, 1.0, 1.0]])
print(np.round(np.linalg.inv(A3), 3))
print(np.allclose(A3 @ np.linalg.inv(A3), np.eye(3)))

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

A3 = np.array([[2.0, 1.0, -1.0],
               [1.0, 3.0, 2.0],
               [1.0, 1.0, 1.0]])
print(np.round(np.linalg.inv(A3), 3))
print(np.allclose(A3 @ np.linalg.inv(A3), np.eye(3)))
