# %% [markdown]
# # 第3章 変形を続けてやる（行列の積）
#
# 『Pythonで学び直す線形代数』第3章のサンプルコードです。
#
# **使い方**
#
# 1. まず下の「設定セル」のセルを選んで、左の「▶」を押す(または Shift+Enter)。1回だけでOKです。
# 2. あとは各 LESSON のコードを、上から順に「▶」で実行してください。
# 3. 本の説明を読みながら試すと、いちばんよく分かります。
#
# コードは書きかえて何度でも試せます。数字を1つ変えて ▶ を押すと、結果がどう変わるかを目で確かめられます。

# %% [markdown]
# ## 設定セル(最初に1回だけ実行)
#
# 日本語をグラフに表示するための準備です。新しく開いたら、まずこのセルを1回実行してください。

# %%
# 設定セル(このノートブックで最初に1回だけ実行してください)
# 日本語をグラフに表示するための準備です
# !pip install matplotlib-fontja -q
import matplotlib_fontja  # noqa: F401
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["font.size"] = 18           # グラフの文字を大きめに
plt.rcParams["figure.figsize"] = (8, 6)  # グラフ自体を大きめに

# %% [markdown]
# ## LESSON 09 変形を2回続けると、どうなるか
#
# 本書の「LESSON 09 変形を2回続けると、どうなるか」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
R = np.array([[0, -1], [1, 0]])   # 90度回す
S = np.array([[1, 1], [0, 1]])    # 倒す（せん断）

v = np.array([1, 0])
print(S @ v)
print(R @ (S @ v))

# %%
e1 = np.array([1, 0])
e2 = np.array([0, 1])
print(R @ (S @ e1))
print(R @ (S @ e2))

# %%
RS = np.array([[0, -1], [1, 1]])
print(RS)

v = np.array([1, 0])
print(RS @ v)

# %%
print(R @ S)
print(np.allclose(R @ S, RS))

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

print(R @ S)
print(np.allclose(R @ S, RS))

# %% [markdown]
# ## LESSON 10 積の規則を、自分で導く
#
# 本書の「LESSON 10 積の規則を、自分で導く」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
def matmul(A, B):
    """行列 A と B の積（numpy の @ を使わずに書く）"""
    kekka = [[0, 0], [0, 0]]
    for i in range(2):              # 答えの何行目か
        for j in range(2):          # 答えの何列目か
            for k in range(2):      # 足し合わせる相手
                kekka[i][j] = kekka[i][j] + A[i][k] * B[k][j]
    return np.array(kekka)


R = np.array([[0, -1], [1, 0]])
S = np.array([[1, 1], [0, 1]])
print(matmul(R, S))
print(np.allclose(matmul(R, S), R @ S))

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

def matmul(A, B):
    """行列 A と B の積（numpy の @ を使わずに書く）"""
    kekka = [[0, 0], [0, 0]]
    for i in range(2):              # 答えの何行目か
        for j in range(2):          # 答えの何列目か
            for k in range(2):      # 足し合わせる相手
                kekka[i][j] = kekka[i][j] + A[i][k] * B[k][j]
    return np.array(kekka)


R = np.array([[0, -1], [1, 0]])
S = np.array([[1, 1], [0, 1]])
print(matmul(R, S))
print(np.allclose(matmul(R, S), R @ S))

# %% [markdown]
# ## LESSON 11 順番を変えると、答えが変わる
#
# 本書の「LESSON 11 順番を変えると、答えが変わる」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
print(R @ S)
print(S @ R)
print(np.allclose(R @ S, S @ R))

# %%
v = np.array([1, 0])
print((R @ S) @ v)
print((S @ R) @ v)

# %%
D1 = np.array([[2, 0], [0, 3]])
D2 = np.array([[5, 0], [0, 7]])
print(np.allclose(D1 @ D2, D2 @ D1))

# %%
E = np.eye(2)
print(E)
print(np.allclose(R @ E, R) and np.allclose(E @ R, R))

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

E = np.eye(2)
print(E)
print(np.allclose(R @ E, R) and np.allclose(E @ R, R))

# %% [markdown]
# ## LESSON 12 3回以上続ける、形を合わせる
#
# 本書の「LESSON 12 3回以上続ける、形を合わせる」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
A = np.array([[2, 0], [0, 1]])
print((R @ S) @ A)
print(R @ (S @ A))
print(np.allclose((R @ S) @ A, R @ (S @ A)))

# %%
print(S @ S @ S)
print(np.linalg.matrix_power(S, 3))

# %%
P = np.array([[1, 2, 3], [4, 5, 6]])
Q = np.array([[1, 0], [0, 1], [1, 1]])
print(P.shape, Q.shape)
print(P @ Q)

# %%
try:
    P @ P
except ValueError as e:
    print("ValueError:", e)

# %%
A = np.array([[2, 1], [1, 1]])
B = np.array([[1, 2], [3, 4]])
print(A[0] @ B[:, 0])
print((A @ B)[0, 0])

# %%
import time

A = np.array([[2.0, 1.0], [1.0, 1.0]])
B = np.array([[1.0, 2.0], [3.0, 4.0]])

start = time.time()
for _ in range(10000):
    matmul(A, B)
print(f"自作 matmul: {time.time() - start:.3f} 秒")

start = time.time()
for _ in range(10000):
    A @ B
print(f"numpy の @ : {time.time() - start:.3f} 秒")

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
rng = np.random.default_rng(42)
big = rng.random((200, 200))

start = time.time()
big @ big
print(f"200x200 の積: {(time.time() - start) * 1000:.1f} ミリ秒")
