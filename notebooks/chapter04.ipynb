# %% [markdown]
# # 第4章 連立方程式を解く
#
# 『Pythonで学び直す線形代数』第4章のサンプルコードです。
#
# **使い方**
#
# 1. まず下の「設定セル」のセルを選んで、左の「▶」を押す(または Shift+Enter)。1回だけでOKです。
# 2. あとは各 LESSON のコードを、上から順に「▶」で実行してください。
# 3. 本の説明を読みながら試すと、いちばんよく分かります。
#
# コードは書きかえて何度でも試せます。数字を1つ変えて ▶ を押すと、結果がどう変わるかを目で確かめられます。

# %% [markdown]
# ## 設定セル(最初に1回だけ実行)
#
# 日本語をグラフに表示するための準備です。新しく開いたら、まずこのセルを1回実行してください。

# %%
# 設定セル(このノートブックで最初に1回だけ実行してください)
# 日本語をグラフに表示するための準備です
# !pip install matplotlib-fontja -q
import matplotlib_fontja  # noqa: F401
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["font.size"] = 18           # グラフの文字を大きめに
plt.rcParams["figure.figsize"] = (8, 6)  # グラフ自体を大きめに

# %% [markdown]
# ## LESSON 13 連立方程式を、行列で書き直す
#
# 本書の「LESSON 13 連立方程式を、行列で書き直す」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
A = np.array([[2.0, 1.0], [1.0, 1.0]])
b = np.array([4.0, 3.0])
x = np.array([1.0, 2.0])

print(A @ x)
print(np.allclose(A @ x, b))

# %%
e1 = np.array([1.0, 0.0])
e2 = np.array([0.0, 1.0])

print(A @ e1)
print(A @ e2)
print(1 * (A @ e1) + 2 * (A @ e2))

# %%
print(np.linalg.solve(A, b))

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

A = np.array([[2.0, 1.0], [1.0, 1.0]])
b = np.array([4.0, 3.0])
x = np.array([1.0, 2.0])

print(A @ x)
print(np.allclose(A @ x, b))

# %% [markdown]
# ## LESSON 14 解き方を、自分の手で書く
#
# 本書の「LESSON 14 解き方を、自分の手で書く」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
M = np.array([[2.0, 1.0, 4.0], [1.0, 1.0, 3.0]])

M[0] = M[0] / M[0][0]       # 1行目の左を 1 に
print(M)
M[1] = M[1] - M[1][0] * M[0]  # 2行目の左を 0 に
print(M)

# %%
M[1] = M[1] / M[1][1]       # 2行目の右を 1 に
print(M)
M[0] = M[0] - M[0][1] * M[1]  # 1行目の右を 0 に
print(M)

# %%
def hakidashi(A, b):
    """掃き出し法で A x = b を解く（行の入れ替えはしない）"""
    n = len(b)
    M = np.hstack([A.astype(float), b.reshape(n, 1).astype(float)])
    for i in range(n):                    # 何列目を片づけるか
        M[i] = M[i] / M[i][i]             # 対角を 1 にする
        for j in range(n):                # 他の行から消す
            if j != i:
                M[j] = M[j] - M[j][i] * M[i]
    return M[:, n]                        # 右端の列が答え


A = np.array([[2.0, 1.0], [1.0, 1.0]])
b = np.array([4.0, 3.0])
print(hakidashi(A, b))
print(np.allclose(hakidashi(A, b), np.linalg.solve(A, b)))

# %%
A3 = np.array([[2.0, 1.0, -1.0],
               [1.0, 3.0, 2.0],
               [1.0, 1.0, 1.0]])
b3 = np.array([3.0, 13.0, 6.0])
print(hakidashi(A3, b3))
print(np.linalg.solve(A3, b3))

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

A3 = np.array([[2.0, 1.0, -1.0],
               [1.0, 3.0, 2.0],
               [1.0, 1.0, 1.0]])
b3 = np.array([3.0, 13.0, 6.0])
print(hakidashi(A3, b3))
print(np.linalg.solve(A3, b3))

# %% [markdown]
# ## LESSON 15 解けないときが、ある
#
# 本書の「LESSON 15 解けないときが、ある」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
C = np.array([[1.0, 2.0], [2.0, 4.0]])
print(C @ np.array([1.0, 0.0]))
print(C @ np.array([0.0, 1.0]))

# %%
try:
    np.linalg.solve(C, np.array([1.0, 3.0]))
except np.linalg.LinAlgError as e:
    print("LinAlgError:", e)

# %%
try:
    np.linalg.solve(C, np.array([1.0, 2.0]))
except np.linalg.LinAlgError as e:
    print("LinAlgError:", e)

# %%
for t in [0.0, 1.0, 2.0, -3.0]:
    x = np.array([1.0 - 2.0 * t, t])
    print(t, C @ x)

# %%
ans, *_ = np.linalg.lstsq(C, np.array([1.0, 2.0]), rcond=None)
print(np.round(ans, 3))
print(np.allclose(C @ ans, np.array([1.0, 2.0])))

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
# 本文の「ちょっと変えてみる」の指示どおりに、下の数字を
# 1か所だけ書きかえて ▶ を押してください。
# (元に戻したいときは、上のセルをもう一度実行すれば戻ります)

ans, *_ = np.linalg.lstsq(C, np.array([1.0, 2.0]), rcond=None)
print(np.round(ans, 3))
print(np.allclose(C @ ans, np.array([1.0, 2.0])))

# %% [markdown]
# ## LESSON 16 行を入れ替える理由
#
# 本書の「LESSON 16 行を入れ替える理由」を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %% [markdown]
# ### 検証

# %%
Ap = np.array([[1e-17, 1.0], [1.0, 1.0]])
bp = np.array([1.0, 2.0])

print(hakidashi(Ap, bp))
print(np.linalg.solve(Ap, bp))

# %%
M = np.hstack([Ap.copy(), bp.reshape(2, 1)])
M[0] = M[0] / M[0][0]
print(M)
M[1] = M[1] - M[1][0] * M[0]
print(M)

# %%
Ap2 = np.array([[1.0, 1.0], [1e-17, 1.0]])
bp2 = np.array([2.0, 1.0])
print(hakidashi(Ap2, bp2))

# %% [markdown]
# ### ちょっと変えてみる
#
# **ここからが本番です。** 本文の指示どおりに数字を1か所だけ書きかえて ▶ を押し、結果がどう変わるかを確かめてください。

# %%
import time

rng = np.random.default_rng(42)
for n in [10, 100, 500]:
    A = rng.random((n, n)) + n * np.eye(n)
    b = rng.random(n)
    start = time.time()
    np.linalg.solve(A, b)
    print(f"{n} 元連立: {(time.time() - start) * 1000:.1f} ミリ秒")
