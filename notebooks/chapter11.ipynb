# %% [markdown]
# # 第11章 大きい行列と、この先へ
#
# 『Pythonで学び直す線形代数』第11章のサンプルコードです。
#
# **使い方**
#
# 1. まず下の「設定セル」のセルを選んで、左の「▶」を押す(または Shift+Enter)。1回だけでOKです。
# 2. あとは各 LESSON のコードを、上から順に「▶」で実行してください。
# 3. 本の説明を読みながら試すと、いちばんよく分かります。
#
# コードは書きかえて何度でも試せます。数字を1つ変えて ▶ を押すと、結果がどう変わるかを目で確かめられます。

# %% [markdown]
# ## 設定セル(最初に1回だけ実行)
#
# 日本語をグラフに表示するための準備です。新しく開いたら、まずこのセルを1回実行してください。

# %%
# 設定セル(このノートブックで最初に1回だけ実行してください)
# 日本語をグラフに表示するための準備です
# !pip install matplotlib-fontja -q
import matplotlib_fontja  # noqa: F401
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["font.size"] = 18           # グラフの文字を大きめに
plt.rcParams["figure.figsize"] = (8, 6)  # グラフ自体を大きめに

# %% [markdown]
# ## LESSON 40 正方形でない行列を分ける
#
# 本書の「LESSON 40 正方形でない行列を分ける」の説明を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %%
A = np.array([[3.0, 1.0], [1.0, 3.0], [2.0, 2.0]])
print(A.shape)
try:
    np.linalg.eig(A)
except np.linalg.LinAlgError as e:
    print(f"LinAlgError: {e}")

# %%
U, s, Vh = np.linalg.svd(A)
print(U.shape, s.shape, Vh.shape)
print(np.round(s, 6))

# %%
U2, s2, Vh2 = np.linalg.svd(A, full_matrices=False)
print(U2.shape, s2.shape, Vh2.shape)
print(np.allclose(U2 @ np.diag(s2) @ Vh2, A))

# %%
print(np.all(np.diff(s) <= 0))

# %%
koyu = np.linalg.eigvalsh(A.T @ A)
print(np.round(np.sqrt(koyu[::-1]), 6))
print(np.allclose(np.sqrt(koyu[::-1]), s))

# %%
C = np.array([[1.0, 2.0], [2.0, 4.0]])
print(np.round(np.linalg.svd(C)[1], 6))
print(np.linalg.matrix_rank(C))

# %% [markdown]
# ## LESSON 41 画像を小さくする
#
# 本書の「LESSON 41 画像を小さくする」の説明を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %%
import matplotlib.cbook as cbook
with cbook.get_sample_data("grace_hopper.jpg") as f:
    im = plt.imread(f)
gazou = im.mean(axis=2)
print(im.shape)
print(gazou.shape)
print(f"{gazou.min():.1f}  {gazou.max():.1f}")

# %%
Ug, sg, Vhg = np.linalg.svd(gazou, full_matrices=False)
print(len(sg))
print(np.round(sg[:5], 1))

# %%
zen = (sg**2).sum()
for k in [5, 10, 50]:
    nokori = (sg[:k]**2).sum() / zen * 100
    moto = gazou.size
    ato = k * (gazou.shape[0] + gazou.shape[1] + 1)
    print(f"k={k:3d}  情報 {nokori:5.2f}%  データ {moto} → {ato} "
          f"({moto / ato:.1f}分の1)")

# %%
for k in [1, 100]:
    nokori = (sg[:k]**2).sum() / zen * 100
    print(f"k={k:3d}  情報 {nokori:5.2f}%")

# %% [markdown]
# ## LESSON 42 計算機は小数を正確に持てない
#
# 本書の「LESSON 42 計算機は小数を正確に持てない」の説明を読みながら、下のコードを上から順に1つずつ ▶ で試してください。

# %%
print(0.1 + 0.2)
print(0.1 + 0.2 == 0.3)
print(np.isclose(0.1 + 0.2, 0.3))

# %%
print(f"{np.finfo(float).eps:.6e}")
print(f"{0.1:.20f}")

# %%
D = np.array([[0.1, 0.2], [0.3, 0.6]])
print(f"{np.linalg.det(D):.6e}")
print(np.linalg.det(D) == 0)
print(np.isclose(np.linalg.det(D), 0))

# %%
print(0.5 + 0.25 == 0.75)
print(f"{0.5:.20f}")
